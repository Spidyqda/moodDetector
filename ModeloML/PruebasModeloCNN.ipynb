# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
from keras.models import model_from_json

# %%
json_file = open("facialemotionmodel.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("facialemotionmodel.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,grayscale =  True )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of sad
# C:\Users\mateo\anaconda3\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 1/1 [==============================] - 0s 448ms/step
# model prediction is  sad

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'images/test/happy/247.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 [==============================] - 0s 54ms/step
# model prediction is  happy
# C:\Users\mateo\anaconda3\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
image = 'images/test/surprise/438.jpg'
print("original image is of surprise")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of surprise
# 1/1 [==============================] - 0s 49ms/step
# model prediction is  surprise

# %%
image = 'images/test/sad/761.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 [==============================] - 0s 46ms/step
# model prediction is  sad

# %%
image = 'images/test/fear/340.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 [==============================] - 0s 47ms/step
# model prediction is  fear

# %%
image = 'images/test/happy/1974.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 [==============================] - 0s 36ms/step
# model prediction is  happy

# %%
image = 'images/test/angry/1575.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of angry
# 1/1 [==============================] - 0s 47ms/step
# model prediction is  angry

# %%
image = 'images/test/neutral/673.jpg'
print("original image is of neutral")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of neutral
# 1/1 [==============================] - 0s 41ms/step
# model prediction is  neutral

# %%
image = 'images/test/disgust/8893.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 [==============================] - 0s 42ms/step
# model prediction is  disgust

# %%
image = 'images/test/happy/895.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 [==============================] - 0s 42ms/step
# model prediction is  sad

# %%
image = 'C:/Users/mateo/OneDrive/Escritorio/prueba/nueba prueba/images/fotoprueba1.png'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 [==============================] - 0s 60ms/step
# model prediction is  sad

# %%
image = 'C:/Users/mateo/OneDrive/Escritorio/prueba/nueba prueba/images/webcam_snapshot_1700250039.png'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 [==============================] - 0s 46ms/step
# model prediction is  fear

# %%
image = 'C:/Users/mateo/OneDrive/Escritorio/prueba/nueba prueba/images/fotoprueba2.png'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 [==============================] - 0s 41ms/step
# model prediction is  sad
